# %%
import tensorflow as tf
import numpy as np

# %%
raw_data = np.random.normal(10, 1, 100)

# %%
alpha = tf.constant(0.05)
curr_value = tf.placeholder(tf.float32)
prev_avg = tf.Variable(0.)
update_avg = alpha * curr_value + (1 - alpha) * prev_avg

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for i in range(len(raw_data)):
        curr_avg = sess.run(update_avg, feed_dict={curr_value: raw_data[i]})
        sess.run(tf.assign(prev_avg, curr_avg))
        print(raw_data[i], curr_avg)
# Out:
# 8.84015678428 0.442008
# 12.3411252995 1.03696
# 9.9966296313 1.48495
# 11.5328903934 1.98734
# 10.7932172769 2.42764
# 11.564203606 2.88447
# 9.96993888236 3.23874
# 9.96386905862 3.575
# 9.48155907856 3.87032
# 10.7902008688 4.21632
# 10.0179164259 4.5064
# 11.0524769015 4.8337
# 10.7322687567 5.12863
# 10.6005724848 5.40223
# 10.0337865549 5.63381
# 11.1903178601 5.91163
# 6.24746331106 5.92842
# 10.4507676396 6.15454
# 9.84973630264 6.3393
# 8.94526310745 6.4696
# 10.9628455128 6.69426
# 10.5557236428 6.88733
# 9.6326691147 7.0246
# 11.7747158475 7.26211
# 9.93916614758 7.39596
# 9.22153154867 7.48724
# 9.49460261685 7.58761
# 8.73827237224 7.64514
# 9.32954183529 7.72936
# 9.82321412133 7.83405
# 11.2402138686 8.00436
# 11.3359068066 8.17094
# 8.06953342538 8.16587
# 11.6450721909 8.33983
# 12.0162290518 8.52365
# 8.75565456918 8.53525
# 11.2513296364 8.67105
# 9.99424600347 8.73721
# 9.80395071323 8.79055
# 10.222004573 8.86212
# 12.970539703 9.06754
# 10.3515605226 9.13174
# 10.2370662242 9.18701
# 9.33737417081 9.19452
# 8.9152722885 9.18056
# 8.74872966586 9.15897
# 8.85566707567 9.1438
# 12.4400350059 9.30862
# 11.2160768384 9.40399
# 8.29239601658 9.34841
# 10.7933257549 9.42065
# 8.14756141608 9.357
# 10.2374059689 9.40102
# 9.0191102835 9.38192
# 10.2283147128 9.42424
# 9.93889661235 9.44998
# 10.2026393501 9.48761
# 11.3247473309 9.57946
# 10.144436202 9.60771
# 10.6062716192 9.65764
# 10.8839199224 9.71896
# 10.2374466398 9.74488
# 10.9529791288 9.80529
# 8.62686142332 9.74636
# 9.14521690964 9.71631
# 8.97420755938 9.6792
# 9.93678915918 9.69208
# 8.59749889688 9.63735
# 10.9172406864 9.70135
# 10.4039287932 9.73648
# 11.504539928 9.82488
# 12.2367916993 9.94547
# 10.0070725647 9.94855
# 10.0024576165 9.95125
# 10.4228030707 9.97483
# 9.47464300424 9.94982
# 10.0938622183 9.95702
# 12.2493604649 10.0716
# 9.20129839518 10.0281
# 11.5696547042 10.1052
# 9.91471608172 10.0957
# 8.55706997994 10.0187
# 9.52152425895 9.99388
# 10.8428639441 10.0363
# 9.50979720225 10.01
# 10.2329696865 10.0212
# 11.3938994347 10.0898
# 10.0768303674 10.0891
# 10.7168337617 10.1205
# 9.47996479576 10.0885
# 9.45337539625 10.0567
# 10.6534447023 10.0866
# 10.3366940584 10.0991
# 9.57253198839 10.0728
# 10.2904141401 10.0836
# 10.3731344047 10.0981
# 10.3478755147 10.1106
# 10.061565073 10.1081
# 11.4156938106 10.1735
# 10.1352919518 10.1716
